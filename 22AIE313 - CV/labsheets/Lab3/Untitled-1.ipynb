# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import cv
import numpy as np

def OTSU(img):
    hist = dict()
    for i in img:
        for j in i:
            if j not in hist:
                hist[j] = 1
            else:
                hist[j] += 1
    return hist

img = cv2.imread('cammeraman.jpeg')
print(OTSU(img))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import cv
# ----> 2 import numpy as np
#       4 def OTSU(img):
#       5     hist = dict()
#
# ModuleNotFoundError: No module named 'numpy'
